# %%
from collections import Counter, defaultdict
import spacy
from emoji import UNICODE_EMOJI

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# %%time
import sys
sys.path.append('../google/tony-sun-intern-project/neutral_generation/')
from make_gender_neutral import is_gendered
# Out:
# CPU times: user 795 µs, sys: 981 µs, total: 1.78 ms
# Wall time: 1.32 ms

# %%
def get_source_target(eval_set):
    with open(f'/Users/tonysun/google/tony-sun-intern-project/evaluation/{eval_set}/source.txt', 'r') as f:
        source = f.readlines()
    
    with open(f'/Users/tonysun/google/tony-sun-intern-project/evaluation/{eval_set}/target.txt', 'r') as f:
        target = f.readlines()
        
    return source, target

# %%
source, target = get_source_target('gendered_test_set')

# %%
len(source), len(target)
# Out:
# (500, 500)

# %%
token_counter = Counter()

for sent in source:
    tokens = sent.lower().split(' ')
    for token in tokens:
        token_counter[token] += 1

# %%
# num of unique tokens
len(token_counter)
# Out:
# 2522

# %%
total_tokens = 0
for token in token_counter:
    total_tokens += token_counter[token]
total_tokens
# Out:
# 6427

# %%
token_counter.most_common(20)
# Out:
# [('the', 274),
#  ('a', 180),
#  ('to', 158),
#  ('he', 146),
#  ('she', 136),
#  ('and', 131),
#  ('her', 122),
#  ('in', 97),
#  ('his', 95),
#  ('was', 93),
#  ('i', 88),
#  ('of', 82),
#  ('for', 63),
#  ('is', 57),
#  ('on', 50),
#  ('that', 47),
#  ('my', 46),
#  ('with', 46),
#  ('has', 38),
#  ('you', 38)]

# %%
from typing import Tuple

def get_difference(old_sent: str, new_sent: str):
    old_words = old_sent.strip().split(' ')
    new_words = new_sent.strip().split(' ')
    
    removed_words = list(set(old_words) - set(new_words))
    added_words = list(set(new_words) - set(old_words))
#     removed_words = list(word for i, word in enumerate(old_words) if word != new_words[i])
#     added_words = list(word for i, word in enumerate(new_words) if word != old_words[i])
    
    return removed_words, added_words

# %%
def get_difference_sent_list(generation, target):
    changes = list()
    num_changes = 0

    for i in range(500):
        diffs = get_difference(generation[i], target[i])
    #     if len(diffs[0]) != len(diffs[1]):
    #         print(diffs)
    #         print(generation[i], target[i])

        changes.append(diffs)
        num_changes = num_changes + len(diffs[1])
    
    return changes, num_changes

# %%
# 1590 / 795 / 795 for perfect count
changes, num_changes = get_difference_sent_list(generation=source, target=target)
num_changes
# Out:
# 743

# %%
# approximation, isn't perfect
# e.g. set subtraction for word diff, 
# e.g. calculation of percent of "correct changes" bc target changes aren't necessarily in source changes

def get_changes(eval_set, generation):
    with open(f'/Users/tonysun/google/tony-sun-intern-project/evaluation/{eval_set}/generations/{generation}/generation.txt', 'r') as f:
        generation = f.readlines()
    
    with open(f'/Users/tonysun/google/tony-sun-intern-project/evaluation/{eval_set}/source.txt', 'r') as f:
        source = f.readlines()
    
    with open(f'/Users/tonysun/google/tony-sun-intern-project/evaluation/{eval_set}/target.txt', 'r') as f:
        target = f.readlines()
        
    source_changes, source_num_changes = get_difference_sent_list(generation=generation, target=source)
    
    target_changes, target_num_changes = get_difference_sent_list(generation=generation, target=target)
        
    return generation, {
        'source_changes': source_changes,
        'source_num_changes': source_num_changes,
        'target_changes': target_changes,
        'target_num_changes': target_num_changes
    }

# %%
def display_num_changes(all_changes):
    source_num_changes, target_num_changes = all_changes['source_num_changes'], all_changes['target_num_changes']
    correct_changes = source_num_changes - target_num_changes
    
    print(source_num_changes, target_num_changes, correct_changes)
    
    if source_num_changes == 0:
        if target_num_changes == 0:
            print("no changes made")
        else:
            print("no changes made, but generation != target")
    else:
        print('percent of changes that were correct (precision): ', 1 - round(target_num_changes / source_num_changes, 3))
    
    if num_changes == 0:
        print("no changes should be made")
    else:
        print('percent of correct changes captured (recall): ', round(correct_changes / num_changes, 3))

# %%
def display_mistake_counts(mistake_counts):
    print(f"Total of ({mistake_counts['total']}) words in the annotation were not in the generation. Mistakes came from ({mistake_counts['wrong_sentences']}) sentences.")
    print(f"({mistake_counts['subtotal_pronouns_verbs']}) of the mistakes tagged as pronouns / verbs, and ({mistake_counts['subtotal_other']}) tagged as other mistakes.")
    print()
    print(f"Breakdown of the ({mistake_counts['subtotal_pronouns_verbs']}) pronouns / verbs mistakes")
    print(f"\t({mistake_counts['male_pronoun'] + mistake_counts['female_pronoun']}) pronouns: ({mistake_counts['male_pronoun']}) male, ({mistake_counts['female_pronoun']}) female")
    print(f"\t({mistake_counts['auxiliary'] + mistake_counts['verbs']}) verbs: ({mistake_counts['auxiliary']}) auxiliary, ({mistake_counts['verbs']}) root verbs")
    print()
    print(f"Breakdown of the ({mistake_counts['subtotal_other']}) other mistakes")
    print(f"\t({mistake_counts['emoji']}) emoji, ({mistake_counts['symbols']}) symbols, ({mistake_counts['whitespace']}) whitespace, ({mistake_counts['nonbreaking_space']}) non-breaking space")
    print(f"\t({mistake_counts['not_categorized']}) not_categorized")

# %%
def is_emoji(character):
    return character in UNICODE_EMOJI

# %%
GENDER_NEUTRAL_PRONOUNS = ['they', 'their', 'them', 'theirs', 'themself']
SYMBOLS = '!@#$%^&*()_+={}[]\|"\':;?/>.<,~`'

# %%
def analyze_target_changes(all_changes, generation):
    target_changes = all_changes['target_changes']
    
    mistake_counts = Counter()
    mistake_types = defaultdict(list)
    
    for i, full_change in enumerate(target_changes):
        target_change = full_change[1]
#         print(target_change)

        if len(target_change) > 0:
            mistake_counts['wrong_sentences'] += 1
        
        for change in target_change:
            mistake_counts['total'] += 1
            categorized = False
            
            # whitespace
            if not change:
                mistake_counts['whitespace'] += 1
                mistake_types['whitespace'].append(change)
                categorized = True
#                 continue
            
            # non-breaking space \xa0
            if '\xa0' in change:
                mistake_counts['nonbreaking_space'] += 1
                mistake_types['nonbreaking_space'].append(change)
                categorized = True
#                 continue
            
            # pronoun lowercase
            for pronoun in GENDER_NEUTRAL_PRONOUNS:
                if pronoun in change.lower() and change:
                    categorized = True
                    gender = is_gendered(source[i])
    #                 print(source[i], gender)
                    if gender == 'male':
                        mistake_counts['male_pronoun'] += 1
                        mistake_types['male_pronoun'].append(change)
                    elif gender == 'female':
                        mistake_counts['female_pronoun'] += 1
                        mistake_types['female_pronoun'].append(change)
                    break
#                 continue
            
            # verb or auxiliary verb
            if change:
                doc = nlp(change)
                if doc[0].pos_ == 'VERB':
                    mistake_counts['verb'] += 1
                    mistake_types['verb'].append(change)
                    categorized = True
#                 continue
                
                if doc[0].pos_ == 'AUX':
                    mistake_counts['auxiliary'] += 1
                    mistake_types['auxiliary'].append(change)
                    categorized = True
#                     print(generation[i], target[i])
#                 continue

            for c in change:
                if is_emoji(c):
                    mistake_counts['emoji'] += 1
                    mistake_types['emoji'].append(change)
                    categorized = True
                    break

            for c in change:
                if c in SYMBOLS:
                    mistake_counts['symbols'] += 1
                    mistake_types['symbols'].append(change)
                    categorized = True
                    break
            
            if not categorized:
                mistake_counts['not_categorized'] += 1
                mistake_types['not_categorized'].append(change)
#                 print(generation[i])
#                 print(target[i])
    
    mistake_counts['subtotal_pronouns_verbs'] = mistake_counts['auxiliary'] + mistake_counts['verb'] + \
                                        mistake_counts['male_pronoun'] + mistake_counts['female_pronoun']
    mistake_counts['subtotal_other'] = mistake_counts['symbols'] + mistake_counts['emoji'] + mistake_counts['whitespace'] + \
                                mistake_counts['not_categorized'] + mistake_counts['nonbreaking_space']
                
    return mistake_counts, mistake_types

# %%
source, target = get_source_target('gendered_test_set')
changes, num_changes = get_difference_sent_list(generation=source, target=target)

# %%
generation, model_full_changes = get_changes(eval_set='gendered_test_set', generation='model_full')
display_num_changes(model_full_changes)
print()

mistake_counts, mistake_types = analyze_target_changes(model_full_changes, generation)
display_mistake_counts(mistake_counts)
mistake_types
# Out:
# 765 78 687
# percent of changes that were correct (precision):  0.898
# percent of correct changes captured (recall):  0.925
#
# Total of (78) words in the annotation were not in the generation. Mistakes came from (60) sentences.
# (42) of the mistakes tagged as pronouns / verbs, and (48) tagged as other mistakes.
#
# Breakdown of the (42) pronouns / verbs mistakes
# 	(18) pronouns: (6) male, (12) female
# 	(15) verbs: (15) auxiliary, (0) root verbs
#
# Breakdown of the (48) other mistakes
# 	(12) emoji, (19) symbols, (11) whitespace, (1) non-breaking space
# 	(5) not_categorized
# defaultdict(list,
#             {'female_pronoun': ['#theydontknowrealmusic',
#               'them',
#               'their',
#               'them',
#               'Their',
#               'them',
#               'them',
#               'them',
#               'their',
#               'them',
#               'their',
#               'that?"They'],
#              'symbols': ['#theydontknowrealmusic',
#               'https://t.co/5pLOv35b1y',
#               '@',
#               '@',
#               "they're",
#               '#thrumikeslens',
#               ':|:When',
#               "don't",
#               '#coloursoflife',
#               'pup.⛰🐕😀👍🏽',
#               "don't",
#               'is,',
#               'was...',
#               'Loo-hoo-ser-her.',
#               'say,',
#               'that?"They',
#               'say,',
#               'mountains?"They',
#               "don't"],
#              'emoji': ['mind😂😩',
#               '😋🙌',
#               'Aryn❤❤❤',
#               '😤',
#               '🙌🏽🙌🏽',
#               '✖️',
#               '👌🏽',
#               '🌏',
#               '⚾️💙',
#               'pup.⛰🐕😀👍🏽',
#               '😢',
#               '😂'],
#              'male_pronoun': ['their',
#               'THEIR',
#               "they're",
#               'THEIR',
#               'their',
#               'mountains?"They'],
#              'whitespace': ['', '', '', '', '', '', '', '', '', '', ''],
#              'verb': ['begin…',
#               'Can',
#               'say,',
#               'go',
#               'look',
#               'decide',
#               'ask',
#               'tell',
#               'say,'],
#              'nonbreaking_space': ['job\xa0'],
#              'not_categorized': ['but',
#               'where',
#               'and',
#               'spokesperson',
#               'love'],
#              'auxiliary': ["don't",
#               "don't",
#               'was',
#               'is',
#               'is,',
#               'be',
#               'was',
#               'was',
#               'was',
#               'was',
#               'was...',
#               'is',
#               'is',
#               'was',
#               "don't"]})

# %%
generation, convert_changes = get_changes(eval_set='gendered_test_set', generation='convert')
display_num_changes(convert_changes)
print()

mistake_counts, mistake_types = analyze_target_changes(convert_changes, generation)
display_mistake_counts(mistake_counts)
mistake_types
# Out:
# 722 34 688
# percent of changes that were correct (precision):  0.953
# percent of correct changes captured (recall):  0.926
#
# Total of (34) words in the annotation were not in the generation. Mistakes came from (29) sentences.
# (32) of the mistakes tagged as pronouns / verbs, and (11) tagged as other mistakes.
#
# Breakdown of the (32) pronouns / verbs mistakes
# 	(16) pronouns: (5) male, (11) female
# 	(9) verbs: (9) auxiliary, (0) root verbs
#
# Breakdown of the (11) other mistakes
# 	(0) emoji, (9) symbols, (0) whitespace, (0) non-breaking space
# 	(2) not_categorized
# defaultdict(list,
#             {'male_pronoun': ['their',
#               "they're",
#               'THEIR',
#               'their',
#               'mountains?"They'],
#              'symbols': ["they're",
#               "They're",
#               '*them',
#               'was.',
#               'say,',
#               'say:',
#               'that?"They',
#               'say,',
#               'mountains?"They'],
#              'female_pronoun': ['their',
#               'them',
#               'them',
#               "They're",
#               'them',
#               '*them',
#               'them',
#               'them',
#               'their',
#               'them',
#               'that?"They'],
#              'auxiliary': ['be',
#               'was',
#               'was',
#               'was.',
#               'were',
#               'was',
#               'is',
#               'is',
#               'have'],
#              'not_categorized': ['spokesperson', 'love'],
#              'verb': ['say,', 'go', 'look', 'decide', 'say:', 'tell', 'say,']})

# %%
generation, model_simple_augmentation_changes = get_changes(eval_set='gendered_test_set', generation='model_simple_augmentation')
display_num_changes(model_simple_augmentation_changes)
print()

mistake_counts, mistake_types = analyze_target_changes(model_simple_augmentation_changes, generation)
display_mistake_counts(mistake_counts)
mistake_types
# Out:
# 133 865 -732
# percent of changes that were correct (precision):  -5.504
# percent of correct changes captured (recall):  -0.985
#
# Total of (865) words in the annotation were not in the generation. Mistakes came from (499) sentences.
# (739) of the mistakes tagged as pronouns / verbs, and (235) tagged as other mistakes.
#
# Breakdown of the (739) pronouns / verbs mistakes
# 	(583) pronouns: (293) male, (290) female
# 	(96) verbs: (96) auxiliary, (0) root verbs
#
# Breakdown of the (235) other mistakes
# 	(12) emoji, (154) symbols, (11) whitespace, (1) non-breaking space
# 	(57) not_categorized
# defaultdict(list,
#             {'male_pronoun': ['their…',
#               'they',
#               'their',
#               'their',
#               'They',
#               'their',
#               'they',
#               'them',
#               'they',
#               'their',
#               'them',
#               'their',
#               'they',
#               'they',
#               "They're",
#               "they're",
#               'they',
#               'they',
#               'They…',
#               "They're",
#               'They',
#               'they',
#               'them',
#               'they',
#               'them',
#               "they'll",
#               'their',
#               'they',
#               'their',
#               'they',
#               '"them"',
#               'them',
#               'their',
#               'They',
#               'their',
#               'their',
#               'Mee...them....n',
#               'their',
#               'them?!',
#               'their',
#               'theirs',
#               'They',
#               'their',
#               'their…',
#               'their',
#               'They',
#               'They',
#               'they',
#               'They',
#               'them',
#               'them.',
#               'they',
#               'them!',
#               'themself.',
#               'they',
#               'their',
#               'them',
#               'their',
#               'them.',
#               'they',
#               'They',
#               'they',
#               'Their',
#               'them.',
#               'their',
#               'their',
#               'their',
#               'They',
#               'They',
#               'them',
#               'their',
#               'they',
#               'they',
#               'their',
#               'their',
#               'they',
#               "they're",
#               'their',
#               'them!',
#               "they'd",
#               'they',
#               'them',
#               'their',
#               'their',
#               'them.',
#               'their',
#               'them',
#               'they',
#               'their',
#               'they',
#               'they',
#               "they'd",
#               'their',
#               'them?',
#               'they',
#               'them',
#               'they',
#               'They',
#               'them',
#               'their',
#               'them',
#               'their',
#               'theirs',
#               'they',
#               'Their',
#               'They',
#               'they',
#               'their',
#               "They're",
#               'their',
#               "they're",
#               'They',
#               'they',
#               'They',
#               'Their',
#               'their',
#               'They',
#               'they',
#               'they',
#               'they',
#               'their',
#               'They',
#               'they',
#               'They',
#               'their',
#               'them".',
#               'their',
#               'They',
#               "they're",
#               'their',
#               'They',
#               'their',
#               'they',
#               'They',
#               'their',
#               'their',
#               'their',
#               'They',
#               'their',
#               'they',
#               'their',
#               'they',
#               'they',
#               'They',
#               'their',
#               'their',
#               'they',
#               'their',
#               'them',
#               'they',
#               'they',
#               'their',
#               'they',
#               'them',
#               'They',
#               'They',
#               'Their',
#               'they',
#               'they',
#               'they',
#               'They',
#               'they',
#               'they',
#               'they',
#               'they',
#               'them',
#               'their',
#               'they',
#               'They',
#               "they're",
#               'they',
#               'they',
#               'their',
#               'they',
#               'they',
#               'they',
#               "They're",
#               'their',
#               'their',
#               'they',
#               'they',
#               'their',
#               'their',
#               'them!',
#               'They',
#               'They',
#               'them.',
#               'They',
#               'them',
#               "they're",
#               "they're",
#               "they're",
#               'they',
#               "they're",
#               'them.',
#               'their',
#               'They',
#               'They',
#               'them',
#               'they',
#               "They're",
#               'themself',
#               "They're",
#               'them',
#               'them.',
#               'their',
#               'Their',
#               'them',
#               'they',
#               'their',
#               'They',
#               'They',
#               "they'll",
#               "They'll",
#               'them!',
#               'them.',
#               'them',
#               'them',
#               'they',
#               'They',
#               'they',
#               'They',
#               'them',
#               'They',
#               'their',
#               'They',
#               'their',
#               'their',
#               "they'd",
#               'them',
#               'their',
#               'they',
#               'their',
#               'They',
#               'they',
#               'They',
#               'They',
#               'they',
#               "they're",
#               'they',
#               'they',
#               'their',
#               'They',
#               'They',
#               'they',
#               'They',
#               'their',
#               'they',
#               'they',
#               'they',
#               'their',
#               'They',
#               'they',
#               'their',
#               'their',
#               'they',
#               'their',
#               'their',
#               'them',
#               'They',
#               'They',
#               'they',
#               'their',
#               'they',
#               'they',
#               'they',
#               'they',
#               'They',
#               'they',
#               'them',
#               'their',
#               'they',
#               'their',
#               'they',
#               'them',
#               'they',
#               'their',
#               'their',
#               'they',
#               'they',
#               'them',
#               'their',
#               'their',
#               'They',
#               'they',
#               'mountains?"They',
#               'them!',
#               'them.',
#               'They',
#               'their',
#               'their',
#               'they',
#               'they'],
#              'female_pronoun': ['#theydontknowrealmusic',
#               'them',
#               'They',
#               'Their',
#               "They're",
#               'They',
#               'their',
#               'They',
#               'their',
#               'their',
#               'their',
#               "They're",
#               'them',
#               'they',
#               'They',
#               'them',
#               'their',
#               'them.',
#               'their',
#               'them',
#               'they',
#               'their',
#               'they',
#               'their',
#               'they',
#               'them',
#               'their',
#               'their',
#               'them,',
#               'them…',
#               'their',
#               'them',
#               'their',
#               'they…',
#               'They',
#               'their',
#               'them',
#               "They're",
#               "they're",
#               'Their',
#               'them',
#               'their',
#               'them',
#               "they'd",
#               'They',
#               'their',
#               'them.',
#               'their',
#               "They're",
#               'their',
#               'they',
#               'They',
#               'them',
#               'them.',
#               'them',
#               'They',
#               'them',
#               'they',
#               '*them',
#               'them',
#               'their',
#               'them.',
#               'them',
#               'their',
#               'them',
#               'them',
#               'They',
#               "They'll",
#               'their',
#               'they',
#               "they're",
#               'they',
#               'them?',
#               "they'll",
#               'they',
#               'they',
#               'They',
#               'them',
#               "they'd",
#               'they',
#               'their',
#               'them',
#               'they',
#               'they',
#               'their',
#               'their',
#               'They',
#               'they',
#               'they',
#               'themself',
#               'they',
#               'they',
#               'their',
#               'them?',
#               'they',
#               'they',
#               'they',
#               'they',
#               'them',
#               'them',
#               'them.',
#               'their',
#               "They'll",
#               'them',
#               'them',
#               'their',
#               'they',
#               'their',
#               "they're",
#               'their',
#               'they',
#               'their',
#               'their',
#               'themself',
#               'their',
#               'them',
#               'they',
#               'They',
#               'they',
#               'their',
#               'them.',
#               'they',
#               'they',
#               'they',
#               'They',
#               'their',
#               'they',
#               'their',
#               'their',
#               'their',
#               'they',
#               'They',
#               'they',
#               'they',
#               'they',
#               'they',
#               'They',
#               'They',
#               'they',
#               'them',
#               'They',
#               'they',
#               'themself',
#               'They',
#               'their',
#               'they',
#               'They',
#               'their',
#               'their',
#               'Their',
#               'They',
#               'their',
#               'They',
#               'their',
#               'They',
#               'their',
#               'their',
#               'their',
#               'they',
#               'They',
#               'they',
#               'They',
#               'their',
#               'They',
#               'they',
#               'their',
#               'they',
#               'their',
#               'they',
#               'their',
#               'they',
#               'them',
#               'them',
#               'them',
#               'they',
#               'they',
#               'they',
#               'they',
#               'they',
#               'them.',
#               'themself',
#               "they've",
#               "They're",
#               'they',
#               'Their',
#               "they're",
#               'they',
#               'their',
#               'their',
#               'They',
#               'They',
#               'They',
#               'They',
#               'their',
#               'themself',
#               'They',
#               'They',
#               'They',
#               'they',
#               'them,',
#               'them',
#               'They',
#               'they',
#               'them',
#               'them!',
#               'them!',
#               'their',
#               'them',
#               "They're",
#               "They're",
#               "they're",
#               'them',
#               'their',
#               "They're",
#               "they're",
#               "they're",
#               'they',
#               'They',
#               'They',
#               'their',
#               'they',
#               'They',
#               "They'll",
#               'they',
#               'they',
#               'they',
#               'their',
#               'them,',
#               'They',
#               'their',
#               'their',
#               'them.',
#               'they',
#               'They',
#               'their',
#               'they',
#               'their',
#               'they',
#               'them',
#               'they',
#               'they',
#               'them.',
#               'their',
#               'They',
#               'They',
#               'they',
#               'their',
#               'they',
#               'their',
#               'they',
#               'They',
#               'They',
#               'they',
#               'They',
#               'they',
#               'They',
#               'they',
#               'their',
#               'they',
#               'they',
#               "they'd",
#               'they',
#               'their',
#               'They',
#               'they',
#               'They',
#               'their',
#               'They',
#               'themself',
#               'They',
#               'they',
#               'A:their',
#               'their',
#               'they',
#               'their',
#               'them',
#               'their',
#               'themself',
#               'they',
#               'They',
#               'their',
#               'them',
#               "they'd",
#               'they',
#               'they',
#               'them',
#               'they',
#               'themself,',
#               'their',
#               'that?"They'],
#              'symbols': ['#theydontknowrealmusic',
#               "They're",
#               'https://t.co/5pLOv35b1y',
#               '@',
#               "They're",
#               '@',
#               "They're",
#               "they're",
#               'doe???',
#               '@',
#               'them.',
#               '#thrumikeslens',
#               "They're",
#               'https://t.co/wl2rgQ9FzI',
#               "they'll",
#               'them,',
#               'https://t.co/6Dpo1Gzt23',
#               ':|:When',
#               "don't",
#               '"them"',
#               '#coloursoflife',
#               'Mee...them....n',
#               "They're",
#               "they're",
#               'them?!',
#               'https://t.co/qAO4kOP2hO',
#               'https://t.co/imJIUNUbc0',
#               'pup.⛰🐕😀👍🏽',
#               "they'd",
#               "don't",
#               'them.',
#               'them.',
#               'them!',
#               'https://t.co/7pxntazpwq',
#               'themself.',
#               'https://t.co/y0HQ7LhcbX”',
#               "They're",
#               'them.',
#               '*them',
#               'them.',
#               'them.',
#               'them.',
#               "They'll",
#               'are.',
#               "they're",
#               'them?',
#               "they're",
#               "they'll",
#               'them!',
#               "they'd",
#               "they'd",
#               'them.',
#               '^of',
#               "they'd",
#               'them?',
#               'them?',
#               "They're",
#               "they're",
#               'them.',
#               "They'll",
#               "they're",
#               'agency.',
#               'them".',
#               'handicap.',
#               "they're",
#               'innings.',
#               'record.',
#               'proceedings,',
#               'prayers.',
#               'commerce.',
#               'body.',
#               'abducted.',
#               '"martyrs."',
#               'task.',
#               'said.',
#               'storm,',
#               'violence.',
#               'Mousavi.',
#               '34%',
#               'them.',
#               'situation.',
#               'Mulcaire.',
#               'said.',
#               'month,',
#               'about.',
#               'elections.',
#               'station.',
#               'Jubilee.',
#               'address.',
#               'good;',
#               'bond.',
#               "competitors'",
#               "they're",
#               'was.',
#               'say,',
#               'do.',
#               "They're",
#               'them!',
#               "don't",
#               'them.',
#               "they're",
#               "they're",
#               "they're",
#               "they're",
#               'them.',
#               'them.',
#               "they've",
#               "They're",
#               "They're",
#               "They're",
#               'them.',
#               "they're",
#               'are.',
#               "they'll",
#               "They'll",
#               'them!',
#               'them.',
#               'them,',
#               'them!',
#               'them!',
#               "They're",
#               "They're",
#               "they're",
#               'friend.',
#               "They're",
#               "they're",
#               'business.',
#               "they're",
#               "They'll",
#               'do.',
#               'dealer.',
#               'them,',
#               'them.',
#               'nude.',
#               "they'd",
#               'them.',
#               'say,',
#               'reply,',
#               'asking.',
#               'disappear.',
#               "they'd",
#               "they're",
#               'A:their',
#               "they'd",
#               'themself,',
#               'say:',
#               'that?"They',
#               'go,',
#               'say,',
#               'say,',
#               'mountains?"They',
#               'them!',
#               'them.',
#               "weren't"],
#              'emoji': ['mind😂😩',
#               '😋🙌',
#               'Aryn❤❤❤',
#               '😤',
#               '🙌🏽🙌🏽',
#               '✖️',
#               '👌🏽',
#               '🌏',
#               '⚾️💙',
#               'pup.⛰🐕😀👍🏽',
#               '😢',
#               '😂'],
#              'auxiliary': ['have',
#               'are',
#               'were',
#               'have',
#               'are',
#               'are',
#               'are',
#               'are',
#               'are',
#               "don't",
#               "don't",
#               'are',
#               'are',
#               'are',
#               'were',
#               'are',
#               'are.',
#               'were',
#               'do',
#               'Do',
#               'do',
#               'were',
#               'were',
#               'were',
#               'do',
#               'Have',
#               'were',
#               'are',
#               'were',
#               'have',
#               'were',
#               'were',
#               'have',
#               'been',
#               'have',
#               'be',
#               'were',
#               'were',
#               'are',
#               'have',
#               'were',
#               'have',
#               'are',
#               'get',
#               'were',
#               'were',
#               'were',
#               'were',
#               'are',
#               'were',
#               'were',
#               'were',
#               'were',
#               'do',
#               'was.',
#               'were',
#               'do.',
#               'get',
#               "don't",
#               'were',
#               'were',
#               'were',
#               'were',
#               'get',
#               'have',
#               'were',
#               'are.',
#               'were',
#               'were',
#               'were',
#               'were',
#               'were',
#               'were',
#               'do.',
#               'have',
#               'have',
#               'were',
#               'do',
#               'were',
#               'get',
#               'are',
#               'have',
#               'were',
#               'have',
#               'were',
#               'are',
#               'are',
#               'get',
#               'are',
#               'were',
#               'have',
#               'have',
#               'are',
#               'are',
#               "weren't",
#               'are'],
#              'whitespace': ['', '', '', '', '', '', '', '', '', '', ''],
#              'verb': ['begin…',
#               'make',
#               'satisfy',
#               'infect',
#               'make',
#               'bring',
#               'send',
#               'Can',
#               'need',
#               'represented',
#               'defend',
#               'abducted.',
#               'said.',
#               'want',
#               'expect',
#               'depending',
#               'hacked',
#               'said.',
#               'talking',
#               'say',
#               'say,',
#               'leave',
#               'take',
#               'look',
#               'know',
#               'say',
#               'want',
#               'go',
#               'hit',
#               'want',
#               'tell',
#               'go',
#               'say,',
#               'go',
#               'buy',
#               'asking.',
#               'disappear.',
#               'look',
#               'follow',
#               'come',
#               'want',
#               'begin',
#               'decide',
#               'ask',
#               'tell',
#               'cut',
#               'say:',
#               'find',
#               'write',
#               'go',
#               'make',
#               'go,',
#               'see',
#               'say,',
#               'say',
#               'tell',
#               'need',
#               'tell',
#               'say,',
#               'go'],
#              'not_categorized': ['Manchester',
#               'but',
#               'but',
#               'where',
#               'love',
#               'and',
#               'owe',
#               'like',
#               'like',
#               'by',
#               'major',
#               'a',
#               'and',
#               'support',
#               'government',
#               'of',
#               '40',
#               'percent',
#               'roughly',
#               'outspoken',
#               'interview',
#               'plan',
#               'such',
#               'support',
#               'decision',
#               'militant',
#               'against',
#               'for',
#               'votes',
#               'Mr',
#               'the',
#               'vary',
#               'specific',
#               'right',
#               'on',
#               'to',
#               'countries',
#               'by',
#               'lawyers',
#               'spokesperson',
#               'for',
#               'love',
#               'play',
#               'the',
#               'the',
#               'in',
#               'paint',
#               'burst',
#               'decline',
#               'roll',
#               'fear',
#               'genuine',
#               'study',
#               'police',
#               'officer',
#               'order',
#               'hook'],
#              'nonbreaking_space': ['job\xa0']})
